# %%
import polars as pl
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df_anage = pl.read_csv("../data/anage.csv", infer_schema_length=1000)
df_earthq = pl.read_csv("../data/EarthquakesChile_2000-2024.csv", try_parse_dates=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df_anage = pl.read_csv("../data/anage.csv", infer_schema_length=1000)
#       2 df_earthq = pl.read_csv("../data/EarthquakesChile_2000-2024.csv", try_parse_dates=True)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'read_csv'
